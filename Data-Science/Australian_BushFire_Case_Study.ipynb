# %%
import numpy as np
import pandas as pd

# %%
fires = pd.read_csv('fires-from-space-australia-and-new-zeland/fire_archive_M6_96619.csv')

# %%
fires.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  -11.8070   142.0583       313.0   1.0    1.0  2019-08-01        56
# 1  -11.7924   142.0850       319.3   1.0    1.0  2019-08-01        56
# 2  -12.8398   132.8744       311.6   3.1    1.7  2019-08-01        57
# 3  -14.4306   143.3035       310.1   1.1    1.1  2019-08-01        57
# 4  -12.4953   131.4897       310.3   4.0    1.9  2019-08-01        57
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS          48      6.3       297.3   6.6        D     0
# 1     Terra      MODIS          71      6.3       297.3  11.3        D     0
# 2     Terra      MODIS          42      6.3       298.7  23.1        D     0
# 3     Terra      MODIS          33      6.3       296.1   6.5        D     0
# 4     Terra      MODIS          36      6.3       298.8  27.6        D     0

# %%
fires['acq_date'].unique().tolist()
# Out:
# ['2019-08-01',
#  '2019-08-02',
#  '2019-08-03',
#  '2019-08-04',
#  '2019-08-05',
#  '2019-08-06',
#  '2019-08-07',
#  '2019-08-08',
#  '2019-08-09',
#  '2019-08-10',
#  '2019-08-11',
#  '2019-08-12',
#  '2019-08-13',
#  '2019-08-14',
#  '2019-08-15',
#  '2019-08-16',
#  '2019-08-17',
#  '2019-08-18',
#  '2019-08-19',
#  '2019-08-20',
#  '2019-08-21',
#  '2019-08-22',
#  '2019-08-23',
#  '2019-08-24',
#  '2019-08-25',
#  '2019-08-26',
#  '2019-08-27',
#  '2019-08-28',
#  '2019-08-29',
#  '2019-08-30',
#  '2019-08-31',
#  '2019-09-01',
#  '2019-09-02',
#  '2019-09-03',
#  '2019-09-04',
#  '2019-09-05',
#  '2019-09-06',
#  '2019-09-07',
#  '2019-09-08',
#  '2019-09-09',
#  '2019-09-10',
#  '2019-09-11',
#  '2019-09-12',
#  '2019-09-13',
#  '2019-09-14',
#  '2019-09-15',
#  '2019-09-16',
#  '2019-09-17',
#  '2019-09-18',
#  '2019-09-19',
#  '2019-09-20',
#  '2019-09-21',
#  '2019-09-22',
#  '2019-09-23',
#  '2019-09-24',
#  '2019-09-25',
#  '2019-09-26',
#  '2019-09-27',
# ...
